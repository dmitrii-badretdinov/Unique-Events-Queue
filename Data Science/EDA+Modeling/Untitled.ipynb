# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

# %%
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.max_columns', 200)

# %%
session_df = \
pd.read_parquet(\
"C:/Users/DmitriiOffline/Desktop/Data/Relevant documents/Job Search/Test tasks/Artefact/Data Science Takehome Coding Test ARTEFACT/data/sessions")

# %%
session_profile = session_df.profile_report(
    title="Pandas Profiling Report",
    correlations=None,
    interactions=None,
)

# %%
session_df.shape
# Out:
# (46962, 11)

# %%
display(session_df)
# Out:
#        visitNumber     visitId  visitStartTime      date  \
# 0                1  1489357807      1489357807  20170312
# 1                1  1489354191      1489354191  20170312
# 2                1  1489366631      1489366631  20170312
# 3                1  1489378809      1489378809  20170312
# 4                1  1489340095      1489340095  20170312
# ...            ...         ...             ...       ...
# 46957            1  1489624732      1489624732  20170315
# 46958            1  1489763811      1489763811  20170317
# 46959            1  1489734223      1489734223  20170317
# 46960            1  1496206144      1496206144  20170530
# 46961            1  1496208837      1496208837  20170530
#
# ...

# %%
display(session_df['totals'][0])
# Out:
# {'bounces': None,
#  'hits': 44,
#  'newVisits': 1.0,
#  'pageviews': 37.0,
#  'screenviews': None,
#  'sessionQualityDim': None,
#  'timeOnScreen': None,
#  'timeOnSite': 940.0,
#  'totalTransactionRevenue': 141650000.0,
#  'transactionRevenue': 139650000.0,
#  'transactions': 1.0,
#  'uniqueScreenviews': None,
#  'visits': 1}

# %%
hits_df = \
pd.read_parquet(\
"C:/Users/DmitriiOffline/Desktop/Data/Relevant documents/Job Search/Test tasks/Artefact/Data Science Takehome Coding Test ARTEFACT/data/hits")

# %%
sample_hits_df = hits_df.sample(1000)

# %%
sample_hits_profile = ProfileReport(sample_hits_df, config_file="eda_minimal.yml"
)

# %%
sample_hits_profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\DmitriiOffline\miniconda3\envs\art\lib\site-packages\numpy\core\_methods.py:264: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\DmitriiOffline\miniconda3\envs\art\lib\site-packages\numpy\core\_methods.py:256: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\DmitriiOffline\miniconda3\envs\art\lib\site-packages\numpy\core\fromnumeric.py:3757: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
hits_df.size
# Out:
# 25007191

# %%
display(hits_df)
# Out:
#         hitNumber    time  hour  minute isSecure  isInteraction isEntrance  \
# 0               1       0    15      30     None           True       True
# 1               2   85837    15      31     None           True       None
# 2               3  114232    15      32     None           True       None
# 3               4  148224    15      32     None           True       None
# 4               5  163267    15      32     None           True       None
# ...           ...     ...   ...     ...      ...            ...        ...
# 206666          4  186142    21      52     None           True       None
# 206667          1       0    22      33     None           True       True
# 206668          2   56714    22      34     None           True       None
# 206669          3   93397    22      35     None           True       None
# 206670          4  121517    22      35     None           True       None
#
#        isExit  \
# 0        None
# 1        None
# 2        None
# ...

# %%
hits_df.shape
# Out:
# (206671, 121)
